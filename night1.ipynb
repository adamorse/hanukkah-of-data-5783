# %% [markdown]
# ### Password
#
# So we should be looking at 2017 in the Hebrew calendar, but this is happening before Rosh Hashanah, so we'll need to subtract one extra year.

# %%
5783 - (2022-2017+1)
# Out:
# 5777

# %% [markdown]
# ### Puzzle
#
# Alright, so we're looking at customers. Let's take a look.

# %%
import pandas as pd
customers = pd.read_csv('noahs-customers.csv')
customers.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone
# 0  1960-05-14  805-287-8515
# 1  1978-04-04  516-768-1652
# 2  1969-01-21  727-209-0470
# 3  1953-08-17  607-941-9563
# 4  1983-06-06  212-759-9043

# %% [markdown]
# We need to convert last name to phone number, so let's start by extracting last names

# %%
names = customers['name'].str.split(' ',expand=True)

names.head()
# Out:
#            0       1     2
# 0       Jack   Quinn  None
# 1      David  Powell  None
# 2     Carrie   Green  None
# 3     Steven  Miller  None
# 4  Christine  Powers  None

# %% [markdown]
# It looks like some people have middle names and some don't, so to get last names we'll need to combine columns 1 and 2. While we're at it, let's lowercase the last names for ease.

# %%
customers['lastname'] = names[2].mask(names[2].isnull(),names[1]).str.lower()
customers.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone lastname
# 0  1960-05-14  805-287-8515    quinn
# 1  1978-04-04  516-768-1652   powell
# 2  1969-01-21  727-209-0470    green
# 3  1953-08-17  607-941-9563   miller
# 4  1983-06-06  212-759-9043   powers

# %% [markdown]
# Now, let's convert names to numbers

# %%
phone = {
    'abc':'2',
    'def':'3',
    'ghi':'4',
    'jkl':'5',
    'mno':'6',
    'pqrs':'7',
    'tuv': '8',
    'wxyz':'9'
}

def name2num(name):
    return ''.join([phone[k] for x in name for k in phone.keys() if x in k])

customers['namenum'] = customers['lastname'].apply(name2num)
customers.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate         phone lastname namenum
# 0  1960-05-14  805-287-8515    quinn   78466
# 1  1978-04-04  516-768-1652   powell  769355
# 2  1969-01-21  727-209-0470    green   47336
# 3  1953-08-17  607-941-9563   miller  645537
# 4  1983-06-06  212-759-9043   powers  769377

# %% [markdown]
# Let's convert the phone to match the `namenum` format

# %%
customers['phone'] = customers['phone'].str.replace('-','',regex=False)
customers.head()
# Out:
#    customerid              name          address             citystatezip  \
# 0        1001        Jack Quinn    201 E Park St    Los Angeles, CA 91343
# 1        1002      David Powell   224C Tysens Ln  Staten Island, NY 10306
# 2        1003      Carrie Green  1608 W 53rd Way          Tampa, FL 33614
# 3        1004     Steven Miller    178½ E 7th St      Manhattan, NY 10009
# 4        1005  Christine Powers   270 W 242nd St          Bronx, NY 10463
#
#     birthdate       phone lastname namenum
# 0  1960-05-14  8052878515    quinn   78466
# 1  1978-04-04  5167681652   powell  769355
# 2  1969-01-21  7272090470    green   47336
# 3  1953-08-17  6079419563   miller  645537
# 4  1983-06-06  2127599043   powers  769377

# %% [markdown]
# drumroll please...

# %%
customers[customers['namenum']==customers['phone']]
# Out:
#       customerid            name        address        citystatezip  \
# 2187        3188  Sam Guttenberg  221 Banker St  Brooklyn, NY 11222
#
#        birthdate       phone    lastname     namenum
# 2187  1998-05-30  4888362374  guttenberg  4888362374
