# %% [markdown]
# clues
# - lots of old cats
# - Noah's Market sweatshirt

# %%
import pandas as pd
import numpy as np
full = pd.read_csv('full.csv').drop('Unnamed: 0',axis=1)
full.ordered = pd.to_datetime(full.ordered,infer_datetime_format = True)
full.shipped = pd.to_datetime(full.shipped,infer_datetime_format = True)
full.head()
# Out:
#    customerid                 name                address  \
# 0       11145       Frederick Moss      2855 Bronx Park E
# 1        4140         Linda Porter         559 W 139th St
# 2        6080           Amy Wilson         375 W 123rd St
# 3        5406  Tina Lauren Goodwin  1431B St Nicholas Ave
# 4        7635     Robert Armstrong         620 W 162nd St
#
#           citystatezip   birthdate         phone  orderid             ordered  \
# 0      Bronx, NY 10467  1971-07-15  917-807-7174     1589 2017-02-05 16:15:23
# 1  Manhattan, NY 10031  1979-06-09  516-933-2477     1767 2017-02-07 14:48:09
# 2  Manhattan, NY 10027  1976-06-08  838-660-8339     1934 2017-02-09 11:21:16
# 3  Manhattan, NY 10033  1960-12-10  585-878-9905     2944 2017-02-19 15:52:35
# 4  Manhattan, NY 10032  1982-07-30  516-851-2207     4207 2017-03-05 10:16:19
#
#               shipped  items   total      sku  qty  unit_price  \
# 0 2017-02-05 20:00:00    NaN   33.47  DLI0002    1       10.16
# ...

# %% [markdown]
# Let's start with cats!

# %%
cat = full[full.desc.str.contains('Cat')]
cat.head()
# Out:
#      customerid              name               address         citystatezip  \
# 400        1539  Stephen Anderson           412 3rd Ave  Manhattan, NY 10016
# 401        2239     Ashley Hinton  1454 St Nicholas Ave  Manhattan, NY 10033
# 402        8637   Melissa Morales       285 Convent Ave  Manhattan, NY 10031
# 403        5600      Sarah Greene      63-22 Trimble Rd   Woodside, NY 11377
# 404        2754      Jade Johnson         1947B 3rd Ave  Manhattan, NY 10029
#
#       birthdate         phone  orderid             ordered  \
# 400  1965-07-11  838-270-2593     1988 2017-02-09 20:09:04
# 401  1946-09-12  680-531-9657     2454 2017-02-14 14:05:38
# 402  1990-12-29  516-429-7578     2639 2017-02-16 13:24:01
# 403  2000-11-01  585-805-0046     2801 2017-02-17 19:21:50
# 404  1966-12-27  585-881-6882     3367 2017-02-24 11:09:49
#
#                 shipped  items  total      sku  qty  unit_price  \
# 400 2017-02-09 20:09:04    NaN  62.05  PET0005    1        6.42
# ...

# %%
cat_products = cat.desc.str.split(' ',expand=True)
cat_products.head()
# Out:
#          0    1      2       3  4        5     6
# 400  Vegan  Cat  Food,  Turkey  &  Chicken  None
# 401  Vegan  Cat  Food,  Turkey  &  Chicken  None
# 402  Vegan  Cat  Food,  Turkey  &  Chicken  None
# 403  Vegan  Cat  Food,  Turkey  &  Chicken  None
# 404  Vegan  Cat  Food,  Turkey  &  Chicken  None

# %% [markdown]
# Let's see if there's anything marked `Adult` or `Senior` or anything to do with cataracts?

# %%
cat_products[1].value_counts()
# Out:
# Adult     39372
# Cat       30593
# Senior    14047
# Food        374
# Name: 1, dtype: int64

# %%
senior_cats = full[
    (full.desc.str.contains('Senior')) & 
    (full.desc.str.contains('Cat')) & 
    (full.ordered.dt.year == 2017)]\
    .sort_values(by='qty',ascending=False)
senior_cats.head()
# Out:
#         customerid           name          address              citystatezip  \
# 188321        7675     Anita Koch  106-51 214th St  Queens Village, NY 11429
# 137441        7675     Anita Koch  106-51 214th St  Queens Village, NY 11429
# 188335        7675     Anita Koch  106-51 214th St  Queens Village, NY 11429
# 426628        7675     Anita Koch  106-51 214th St  Queens Village, NY 11429
# 413660       10238  Jeffrey Blair  821 St Anns Ave           Bronx, NY 10456
#
#          birthdate         phone  orderid             ordered  \
# 188321  1955-11-14  315-492-7411     9597 2017-04-27 17:58:04
# 137441  1955-11-14  315-492-7411    12232 2017-05-24 08:35:47
# 188335  1955-11-14  315-492-7411    17450 2017-07-16 11:26:34
# 426628  1955-11-14  315-492-7411     6410 2017-03-26 11:54:54
# 413660  1969-10-11  347-391-4510    25293 2017-10-02 14:32:34
#
#                    shipped  items  total      sku  qty  unit_price  \
# ...

# %% [markdown]
# Let's just try Anita!
#
# Aaaand we're done!
